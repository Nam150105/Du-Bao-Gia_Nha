# %% [markdown]
# # Huấn luyện mô hình dự báo giá nhà
#
# Notebook khám phá dữ liệu và huấn luyện mô hình Random Forest từ `data/house_data.csv`.

# %%
import sys
from pathlib import Path

ROOT = Path.cwd().parent if Path.cwd().name == "notebooks" else Path.cwd()
sys.path.insert(0, str(ROOT / "src"))

import pandas as pd
from utils import clean_data, load_raw_data, train_model, format_vnd

# %%
raw = load_raw_data(ROOT / "data" / "house_data.csv")
print(f"Tổng số bản ghi: {len(raw):,}")
raw.head()

# %%
df = clean_data(raw)
print(f"Sau làm sạch: {len(df):,}")
df[["property_type", "city", "area_m2", "bedrooms", "price_vnd"]].describe()

# %%
metrics = train_model(ROOT / "data" / "house_data.csv", ROOT / "models" / "house_price_model.pkl")
print(f"MAE:  {format_vnd(metrics['mae'])}")
print(f"RMSE: {format_vnd(metrics['rmse'])}")
print(f"R²:   {metrics['r2']:.4f}")
